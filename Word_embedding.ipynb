# %% [markdown]
# <a href="https://colab.research.google.com/github/SureshRajpoot143/AWS_workshop/blob/main/Word_embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Word Embedding is a technique in Natural Language Processing (NLP) that converts words into numerical vectors (arrays of numbers) so that computers can understand the meaning and relationships between words.
#
# Instead of representing words as simple labels, word embeddings represent them as points in a multi-dimensional space.

# %%
# !pip install gensim

# %%
from gensim.models import Word2Vec

# %%
sentences = [
    ["python", "programming", "language"],
    ["java", "programming", "language"],
    ["machine", "learning", "python"],
    ["data", "science", "python"],
    ["artificial", "intelligence", "machine", "learning"]
]

# %%
model = Word2Vec(
    sentences,
    vector_size=100,
    window=5,
    min_count=1,
    workers=4
)

# %%
print(model.wv["python"])
# Out:
# [-5.3623732e-04  2.3643578e-04  5.1034451e-03  9.0094414e-03
#  -9.3031237e-03 -7.1169422e-03  6.4589935e-03  8.9731570e-03
#  -5.0155222e-03 -3.7634422e-03  7.3806429e-03 -1.5335002e-03
#  -4.5366986e-03  6.5541747e-03 -4.8602517e-03 -1.8160517e-03
#   2.8766338e-03  9.9189242e-04 -8.2853707e-03 -9.4489949e-03
#   7.3119029e-03  5.0703571e-03  6.7578200e-03  7.6287985e-04
#   6.3510095e-03 -3.4054297e-03 -9.4641914e-04  5.7686814e-03
#  -7.5217788e-03 -3.9361771e-03 -7.5117229e-03 -9.3005964e-04
#   9.5382975e-03 -7.3193042e-03 -2.3338124e-03 -1.9377774e-03
#   8.0775889e-03 -5.9310072e-03  4.5163288e-05 -4.7538229e-03
#  -9.6037304e-03  5.0073871e-03 -8.7597491e-03 -4.3919077e-03
#  -3.5100642e-05 -2.9618701e-04 -7.6613836e-03  9.6149230e-03
#   4.9821516e-03  9.2333164e-03 -8.1580700e-03  4.4958824e-03
#  -4.1371533e-03  8.2455151e-04  8.4987795e-03 -4.4622603e-03
#   4.5175850e-03 -6.7870873e-03 -3.5485553e-03  9.3986839e-03
# ...

# %%
model.wv.most_similar("python")
# Out:
# [('java', 0.21617145836353302),
#  ('science', 0.09291037917137146),
#  ('data', 0.027057476341724396),
#  ('artificial', 0.016134686768054962),
#  ('learning', -0.01083916425704956),
#  ('programming', -0.027750348672270775),
#  ('machine', -0.052346743643283844),
#  ('intelligence', -0.059876296669244766),
#  ('language', -0.11167057603597641)]

# %%
similarity = model.wv.similarity(
    "python",
    "machine"
)

print(similarity)
# Out:
# -0.05234673
