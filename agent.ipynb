# %% [markdown]
# <a href="https://colab.research.google.com/github/SureshRajpoot143/AWS_workshop/blob/main/agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymupdf transformers torch gtts

# %%
from google.colab import files

uploaded = files.upload()
pdf_file = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-a0990cd6-ad82-4cf8-b484-e1baae232a1a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0990cd6-ad82-4cf8-b484-e1baae232a1a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import fitz

doc = fitz.open(pdf_file)

text = ""

for page in doc:
    text += page.get_text()

print(text[:1000])
# Out:
# Presentation Title
# Presentation Subtitle
# CITY VOICE
# 22JAN2025
# JDU Manipur Chief Pulls
# Support From BJP
# Government In State,
# Party Sacks Him
# इंफाल:
# ǒबहार के मुख्यमंत्रिी नीतीश कुमार की पाटर्टी जनता दल
# (यूनाइटेड) ने अपने मͨणपुर प्रमुख केश बीरेन ͧसंह को
# आज बखार्थस्त कर Ǒदया, जब श्री ͧसंह ने राज्यपाल को पत्रि
# भेजकर कहा ͩक जद (यू) ने भाजपा के नेतृत्व वाली राज्य
# सरकार से समथर्थन वापस ले ͧलया है।
# मͨणपुर ͪवधानसभा में जद (यू) का केवल एक
# ͪवधायक मोहम्मद अब्दुल नाͧसर है। फरवरी-माचर्थ
# 2022 में ͪवधानसभा चुनाव जीतने वाले छह जद
# (यू) उम्मीदवारों में से पांच बाद में सत्तारूढ़ भाजपा
# में शाͧमल हो गए।
# नाटक तब सामने आया जब श्री ͧसंह ने आज एक
# बयान में कहा ͩक उनके ͪवधायक को राज्य में
# ͪवपक्षी सदस्य माना जाएगा।
# Intro
# What’s this presentation about? Use this slide to introduce yourself and give a
# high level overview of the topic you’re about to explain.
# First point
# Lorem ipsum dolor sit amet, consectetur
# adipiscing elit, sed do eiusmod tempor
# ...

# %%
# !pip install --upgrade transformers
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
import logging

logging.basicConfig(level=logging.ERROR) # Set to ERROR to avoid excessive output from transformers

model_name = "facebook/bart-large-cnn"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

try:
    summarizer = pipeline(
        "summarization",
        model=model,
        tokenizer=tokenizer,
        generation_kwargs={"forced_bos_token_id": 0}
    )
except KeyError as e:
    if "Unknown task summarization" in str(e):
        print("\nERROR: The 'summarization' task is not recognized. This often happens after upgrading the transformers library.\n")
        print("Please RESTART THE COLAB RUNTIME (Runtime > Restart runtime or Ctrl+M .) and then re-run all cells.\n")
        raise  # Re-raise the exception to stop execution and highlight the issue
    else:
        raise # Re-raise for other KeyErrors

summary = summarizer(
    text[:3000],
    max_length=200,
    min_length=50,
    do_sample=False
)

summary_text = summary[0]["summary_text"]

print(summary_text)
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] Please make sure the generation config includes `forced_bos_token_id=0`.
# Loading weights:   0%|          | 0/511 [00:00<?, ?it/s]
# ERROR: The 'summarization' task is not recognized. This often happens after upgrading the transformers library.
#
# ...

# %%
from gtts import gTTS
import logging

logging.basicConfig(level=logging.INFO)

if 'summary_text' in locals() and summary_text:
    try:
        tts = gTTS(summary_text)
        tts.save("summary.mp3")
        logging.info("Summary converted to speech and saved as summary.mp3")
    except Exception as e:
        logging.error(f"Error generating or saving audio: {e}")
        logging.warning("Failed to generate audio from summary. Please check the 'summary_text' content and gTTS installation.")
else:
    logging.error("Error: 'summary_text' is not defined or is empty. Please ensure the summarization cell (hiHTJETbd95F) ran successfully after restarting the runtime.")
    # Optionally, create a dummy audio file or handle the error gracefully without stopping execution.
    # For example, to create a dummy audio file:
    # tts = gTTS("Summary not available. Please generate the summary first.")
    # tts.save("summary_not_available.mp3")
    # logging.info("Created 'summary_not_available.mp3' as a placeholder.")
# Out:
# ERROR:root:Error: 'summary_text' is not defined or is empty. Please ensure the summarization cell (hiHTJETbd95F) ran successfully after restarting the runtime.

# %%
from IPython.display import Audio
import os

if os.path.exists("summary.mp3"):
    Audio("summary.mp3")
else:
    print("WARNING: 'summary.mp3' not found. This usually means the summarization and audio generation steps failed.")
    print("Please ensure the previous cells ran successfully, especially the summarization cell (hiHTJETbd95F).")
    print("If you encountered 'KeyError: Unknown task summarization', please RESTART THE COLAB RUNTIME (Runtime > Restart runtime or Ctrl+M .) and then re-run all cells from the beginning.")
# Out:
# WARNING: 'summary.mp3' not found. This usually means the summarization and audio generation steps failed.
# Please ensure the previous cells ran successfully, especially the summarization cell (hiHTJETbd95F).
# If you encountered 'KeyError: Unknown task summarization', please RESTART THE COLAB RUNTIME (Runtime > Restart runtime or Ctrl+M .) and then re-run all cells from the beginning.

# %%
if 'summarizer' not in locals():
    print("Error: The 'summarizer' object is not defined. This usually happens if the summarization setup cell (hiHTJETbd95F) failed.\n")
    print("Please RESTART THE COLAB RUNTIME (Runtime > Restart runtime or Ctrl+M .) and then re-run all cells from the beginning to resolve the 'KeyError'.")
else:
    for i, page in enumerate(doc):
        page_text = page.get_text()

        # Limit text length to avoid token limits for summarizer
        # A typical BART model has a max input length of 1024 tokens. 2000 characters is a safe approximation.
        result = summarizer(
            page_text[:2000],
            max_length=100,
            min_length=30
        )

        print(f"Page {i+1}")
        print(result[0]["summary_text"])
# Out:
# Error: The 'summarizer' object is not defined. This usually happens if the summarization setup cell (hiHTJETbd95F) failed.
#
# Please RESTART THE COLAB RUNTIME (Runtime > Restart runtime or Ctrl+M .) and then re-run all cells from the beginning to resolve the 'KeyError'.

# %%
# !pip install pyttsx3

# %%
# !pip install pyttsx3
import pyttsx3

if 'summary_text' in locals() and summary_text:
    engine = pyttsx3.init()
    engine.say(summary_text)
    engine.runAndWait()
else:
    print("Error: 'summary_text' is not defined. This means the summarization step failed.\n")
    print("Please RESTART THE COLAB RUNTIME (Runtime > Restart runtime or Ctrl+M .) and then re-run all cells from the beginning to resolve the underlying 'KeyError' in the summarization pipeline.")
# Out:
# ...
# Error: 'summary_text' is not defined. This means the summarization step failed.
#
# Please RESTART THE COLAB RUNTIME (Runtime > Restart runtime or Ctrl+M .) and then re-run all cells from the beginning to resolve the underlying 'KeyError' in the summarization pipeline.
